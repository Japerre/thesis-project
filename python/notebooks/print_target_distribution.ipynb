# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\tibol\Desktop\FIIW Tibo Laperre\fase 5 - thesis\thesis-projectV2\data\input\datasets\income_binned_USA_1664500\income_binned_USA_1664500.csv'
df = pd.read_csv(path, delimiter=';')

# %%
# Plot a bar plot of the 'class' column
class_counts = df['PINCP'].value_counts()
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('target')
plt.ylabel('Count')
plt.title('PINCP Distribution full dataset')
plt.show()

# %%
rel_counts = df['WIFEREL'].value_counts()
plt.bar(rel_counts.index, rel_counts.values)
plt.xlabel('rel')
plt.ylabel('Count')
plt.title('wife religion Distribution full dataset')
plt.show()
