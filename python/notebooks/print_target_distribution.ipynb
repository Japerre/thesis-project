# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\tibol\Desktop\FIIW Tibo Laperre\fase 5 - thesis\thesis-projectV3\data\input\datasets\nursery\nursery.csv'
# path = r'C:\Users\tibol\Desktop\FIIW Tibo Laperre\fase 5 - thesis\thesis-projectV3\data\input\datasets\cmc\cmc.csv'
# path = r'C:\Users\tibol\Desktop\FIIW Tibo Laperre\fase 5 - thesis\thesis-projectV3\data\input\datasets\ACSIncome_USA_2018_binned_imbalanced_1664500\ACSIncome_USA_2018_binned_imbalanced_1664500.csv'
df = pd.read_csv(path, delimiter=';')

# %%
# new_labels = ['no-use','short-term','long-term']
# new_labels = ['medium','poor','rich']
class_counts = df['class'].value_counts(normalize=True)*100
# ACSIncome_labels_dict = dict(zip(class_counts.index, new_labels))
# class_counts.index = [ACSIncome_labels_dict[idx] for idx in class_counts.index]
plt.bar(class_counts.index, class_counts.values)
# plt.xlabel('target')
plt.ylabel('Percentage(%)')
# plt.title('Target distributie nursery')
plt.show()

# %%
rel_counts = df['WIFEREL'].value_counts()
plt.bar(rel_counts.index, rel_counts.values)
plt.xlabel('rel')
plt.ylabel('Count')
plt.title('wife religion Distribution full dataset')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\tibol\anaconda3\envs\folktables\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\tibol\anaconda3\envs\folktables\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\tibol\anaconda3\envs\folktables\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WIFEREL'
#
# The above exception was the direct cause of the following exception:
#
# ...
